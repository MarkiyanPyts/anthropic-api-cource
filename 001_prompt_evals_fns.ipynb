# %%
# Load env variables and create client
from dotenv import load_dotenv
from anthropic import Anthropic

load_dotenv()

client = Anthropic()
model = "claude-haiku-4-5"

# %%
# Helper functions
def add_user_message(messages, text):
    user_message = {"role": "user", "content": text}
    messages.append(user_message)


def add_assistant_message(messages, text):
    assistant_message = {"role": "assistant", "content": text}
    messages.append(assistant_message)


def chat(messages, system=None, temperature=1.0, stop_sequences=[]):
    params = {
        "model": model,
        "max_tokens": 1000,
        "messages": messages,
        "temperature": temperature,
        "stop_sequences": stop_sequences,
    }

    if system:
        params["system"] = system

    message = client.messages.create(**params)
    return message.content[0].text

# %%
# Function to generate a new dataset
import json


def generate_dataset():
    prompt = """
Generate a evaluation dataset for a prompt evaluation. The dataset will be used to evaluate prompts
that generate Python, JSON, or Regex specifically for AWS-related tasks. Generate an array of JSON objects,
each representing task that requires Python, JSON, or a Regex to complete.

Example output:
```json
[
    {
        "task": "Description of task, explicitly mention that the solution should be in Python, JSON, or Regex",
        "format": "json" or "python" or "regex",
        "solution_criteria": "Description of what a correct solution should look like"
    },
    ...additional
]
```

* Focus on tasks that can be solved by writing a single Python function, a single JSON object, or a regular expression.
* Focus on tasks that do not require writing much code
* Do not include any comments in the code solutions, only the code itself.

Please generate 3 objects.
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```json")
    text = chat(messages, stop_sequences=["```"])
    return json.loads(text)

# %%
# Generate the dataset and write it to 'dataset.json'
dataset = generate_dataset()
with open("dataset.json", "w") as f:
    json.dump(dataset, f, indent=2)

# %%
# Function to grade a test case + output using a model
def grade_by_model(test_case, output):
    eval_prompt = f"""
You are an expert AWS code reviewer. Your task is to evaluate the following AI-generated solution.

Original Task:
<task>
{test_case["task"]}
</task>

Solution to Criteria:
<criteria>
{test_case["solution_criteria"]}
</criteria>

Solution to Evaluate:
<solution>
{output}
</solution>

Output Format
Provide your evaluation as a structured JSON object with the following fields, in this specific order:
- "strengths": An array of 1-3 key strengths
- "weaknesses": An array of 1-3 key areas for improvement
- "reasoning": A concise explanation of your overall assessment
- "score": A number between 1-10

Respond with JSON. Keep your response concise and direct.
Example response shape:
{{
    "strengths": string[],
    "weaknesses": string[],
    "reasoning": string,
    "score": number
}}
    """

    messages = []
    add_user_message(messages, eval_prompt)
    add_assistant_message(messages, "```json")
    eval_text = chat(messages, stop_sequences=["```"])
    return json.loads(eval_text)

# %%
# Passes a test case into Claude
def run_prompt(test_case):
    prompt = f"""
Please solve the following task:

{test_case["task"]}

* Respond only with Python, JSON, or a plain Regex
* Do not add any comments or commentary or explanation
"""

    messages = []
    add_user_message(messages, prompt)
    add_assistant_message(messages, "```code")
    output = chat(messages, stop_sequences=["```"])
    return output

# %%
# Functions to validate the output structure
import re
import ast


def validate_json(text):
    try:
        json.loads(text.strip())
        return 10
    except json.JSONDecodeError:
        return 0


def validate_python(text):
    try:
        ast.parse(text.strip())
        return 10
    except SyntaxError:
        return 0


def validate_regex(text):
    try:
        re.compile(text.strip())
        return 10
    except re.error:
        return 0


def grade_syntax(response, test_case):
    format = test_case["format"]
    if format == "json":
        return validate_json(response)
    elif format == "python":
        return validate_python(response)
    else:
        return validate_regex(response)

# %%
# Function to execute a single test case and grade the output
def run_test_case(test_case):
    """Calls run_prompt, then grades the result"""
    output = run_prompt(test_case)

    model_grade = grade_by_model(test_case, output)
    model_score = model_grade["score"]
    reasoning = model_grade["reasoning"]

    syntax_score = grade_syntax(output, test_case)

    score = (model_score + syntax_score) / 2

    return {
        "output": output,
        "test_case": test_case,
        "score": score,
        "reasoning": reasoning,
    }

# %%
from statistics import mean


def run_eval(dataset):
    """Loads the dataset and calls run_test_case with each case"""
    results = []

    for test_case in dataset:
        result = run_test_case(test_case)
        results.append(result)

    average_score = mean([result["score"] for result in results])
    print(f"Average score: {average_score}")

    return results

# %%
with open("dataset.json", "r") as f:
    dataset = json.load(f)

results = run_eval(dataset)
# Out:
# Average score: 8.0

# %%
print(json.dumps(results, indent=2))
# Out:
# [
#   {
#     "output": "\nimport re\n\ndef extract_region_from_s3_uri(uri):\n    # Try to extract region from bucket name (most common pattern)\n    match = re.search(r's3://[^/]*-(us|eu|ap|ca|sa|af|me)-(east|west|south|north|central)-\\d+', uri)\n    if match:\n        return match.group(0).split('/')[-1].rsplit('-', 1)[0]\n    \n    # Extract bucket name\n    bucket_match = re.search(r's3://([^/]+)', uri)\n    if bucket_match:\n        bucket_name = bucket_match.group(1)\n        # Extract region from bucket name\n        region_match = re.search(r'(us|eu|ap|ca|sa|af|me)-(east|west|south|north|central)-\\d+', bucket_name)\n        if region_match:\n            return region_match.group(0)\n    \n    return None\n\n# Test\nprint(extract_region_from_s3_uri('s3://my-bucket-us-east-1/path/to/file.txt'))\n",
#     "test_case": {
#       "task": "Extract the AWS region from an S3 bucket URI. Given a string like 's3://my-bucket-us-east-1/path/to/file.txt', extract just the region code.",
#       "format": "regex",
#       "solution_criteria": "A regex pattern that captures the region identifier (e.g., 'us-east-1', 'eu-west-1') from S3 bucket URIs and paths. Should work with various AWS region formats."
#     },
#     "score": 7.5,
#     "reasoning": "The solution correctly identifies that regions follow AWS naming patterns and implements a working regex for common cases. However, it's built on a flawed premise: S3 bucket URIs don't reliably contain region information unless the bucket name itself was intentionally named to include it. The first regex is unnecessarily complicated with confusing extraction logic. A production solution would need to either: (1) acknowledge this is only for specially-named buckets and simplify the code, or (2) use boto3's get_bucket_location() API for authoritative region detection. The code will work for the specific example given but fails to address the fundamental AWS architectural constraint."
#   },
#   {
#     "output": "\nimport re\nimport json\nimport sys\n\ndef parse_cloudwatch_log(log_entry):\n    pattern = r'\\[([^\\]]+)\\]\\s+\\[([^\\]]+)\\]\\s+(.+)'\n    match = re.match(pattern, log_entry)\n    \n    if match:\n        return {\n            \"timestamp\": match.group(1),\n            \"level\": match.group(2),\n            \"message\": match.group(3)\n        }\n    return None\n\nif __name__ == \"__main__\":\n    log_entry = sys.stdin.read().strip()\n    result = parse_cloudwatch_log(log_entry)\n    if result:\n        print(json.dumps(result))\n    else:\n        print(json.dumps({\"error\": \"Invalid log format\"}))\n",
#     "test_case": {
#       "task": "Parse an AWS CloudWatch log entry and extract the timestamp, log level, and message. The log format is: '[TIMESTAMP] [LEVEL] message text here'",
#       "format": "python",
#       "solution_criteria": "A Python function that takes a log string and returns a dictionary with 'timestamp', 'level', and 'message' keys. Should handle various timestamp formats and log levels (INFO, ERROR, WARNING, DEBUG)."
#     },
#     "score": 8.0,
#     "reasoning": "The solution meets the basic requirements by parsing the specified log format and returning the correct dictionary structure. However, it lacks robustness in validation. The regex pattern is appropriate for the format, but the function doesn't validate that the extracted level is one of the expected log levels or that the timestamp is in a valid format. The solution would benefit from stricter validation and handling of edge cases like empty inputs or messages with special characters. The CLI interface is a nice addition but not required by the criteria."
#   },
#   {
#     "output": "\n{\n  \"FunctionName\": \"my-lambda-function\",\n  \"Runtime\": \"python3.11\",\n  \"Handler\": \"index.lambda_handler\",\n  \"Timeout\": 30,\n  \"MemorySize\": 128\n}\n",
#     "test_case": {
#       "task": "Create a JSON configuration object for an AWS Lambda function that includes the function name, runtime, handler, timeout, and memory allocation.",
#       "format": "json",
#       "solution_criteria": "A valid JSON object with required Lambda configuration properties including functionName, runtime (e.g., 'python3.11'), handler (e.g., 'index.handler'), timeoutSeconds, and memoryMB. Should follow AWS Lambda naming conventions."
#     },
#     "score": 8.5,
#     "reasoning": "The solution is a valid and functional AWS Lambda configuration that meets the core requirement of including all five specified properties. However, there's a mismatch between the criteria's camelCase naming convention (functionName, memoryMB) and the solution's use of PascalCase property names, which actually aligns with official AWS CloudFormation/SDK conventions but contradicts the stated criteria. The configuration values are appropriate, though additional optional properties would enhance real-world applicability."
#   }
# ]
